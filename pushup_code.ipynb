# %%
# Push-up Counter with XP and Fixes for Real Detection
import cv2
import numpy as np
from ultralytics import YOLO
from collections import deque
import os

def calculate_angle(a, b, c):
    a, b, c = np.array(a), np.array(b), np.array(c)
    ba = a - b
    bc = c - b
    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    return np.degrees(np.arccos(np.clip(cosine_angle, -1.0, 1.0)))

def get_elbow_angle_with_confidence(keypoints, confs):
    try:
        # Left arm
        ls, le, lw = keypoints[5], keypoints[7], keypoints[9]
        l_conf = min(confs[5], confs[7], confs[9])
        l_angle = calculate_angle(ls, le, lw) if l_conf > 0.3 else None

        # Right arm
        rs, re, rw = keypoints[6], keypoints[8], keypoints[10]
        r_conf = min(confs[6], confs[8], confs[10])
        r_angle = calculate_angle(rs, re, rw) if r_conf > 0.3 else None

        if l_angle and r_angle:
            return min(l_angle, r_angle)
        return l_angle or r_angle
    except:
        return None

class PushupCounter:
    def __init__(self, model_name='yolo11s-pose.pt'):
        self.model = YOLO(model_name)
        self.count = 0
        self.stage = 'up'
        self.down_threshold = 110
        self.up_threshold = 145
        self.angle_history = deque(maxlen=5)
        self.frame_count = 0
        self.last_count_frame = -15
        self.cooldown_frames = 15


    def detect(self, frame):
        results = self.model(frame)
        keypoints = results[0].keypoints.xy[0].cpu().numpy() if results[0].keypoints is not None else None
        confs = results[0].keypoints.conf[0].cpu().numpy() if results[0].keypoints.conf is not None else None
        return results[0], keypoints, confs

    def update(self, angle):
        if angle is None:
            return False

        self.angle_history.append(angle)
        smoothed = np.mean(self.angle_history)

        detected = False
        current_frame = self.frame_count

        if smoothed < self.down_threshold and self.stage == 'up':
            self.stage = 'down'

        elif smoothed > self.up_threshold and self.stage == 'down':
            if (current_frame - self.last_count_frame) > self.cooldown_frames:
                self.stage = 'up'
                self.count += 1
                self.last_count_frame = current_frame
                detected = True

        return detected
    
def process_pushups(video_path, model_name='yolo11s-pose.pt', output_path="output_pushup.mp4"):
    counter = PushupCounter(model_name)
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Video load failed.")
        return

    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))
    milestone_timer = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        counter.frame_count += 1
        result, keypoints, confs = counter.detect(frame)
        if keypoints is not None:
            frame = result.plot()

        angle = get_elbow_angle_with_confidence(keypoints, confs)
        detected = counter.update(angle)

        if detected:
            overlay = frame.copy()
            cv2.rectangle(overlay, (0, 0), (width, height), (0, 128, 255), -1)
            frame = cv2.addWeighted(frame, 0.8, overlay, 0.2, 0)
            cv2.putText(frame, "PUSH-UP!", (width//2 - 100, height//2), cv2.FONT_HERSHEY_SIMPLEX, 2.0, (255,255,255), 4)
            if counter.count % 10 == 0:
                milestone_timer = 30

        y = 60
        cv2.putText(frame, f"PUSH-UPS: {counter.count}", (20, y), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 100), 4)
        y += 50
        cv2.putText(frame, f"XP: {counter.count * 10}", (width - 250, y), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (255, 150, 50), 4)

        if angle:
            cv2.putText(frame, f"Angle: {angle:.1f}", (width - 250, height - 20), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 255, 0), 2)

        if milestone_timer > 0:
            cv2.putText(frame, "💪 YOU ROCK! 💪", (width//2 - 240, height//2 - 60), cv2.FONT_HERSHEY_SIMPLEX, 1.8, (0, 255, 255), 6)
            milestone_timer -= 1

        out.write(frame)

    cap.release()
    out.release()
    print(f"Done: {output_path}")

if __name__ == "__main__":
    VIDEO_DIR = "/Users/shruti.kalaskar/Documents/Northwestern/Spring 2025/Computer Vision/Project/"
    MODEL_NAME = "yolo11s-pose.pt"
    video_files = ["push_up_1.mp4", "push_up_2.mp4"]
    for file in video_files:
        input_path = os.path.join(VIDEO_DIR, file)
        output_path = os.path.join(VIDEO_DIR, file.replace(".mp4", "_output.mp4"))
        process_pushups(input_path, MODEL_NAME, output_path)
# Out:
# 0: 384x640 1 person, 183.6ms
# Speed: 1.7ms preprocess, 183.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.6ms
# Speed: 1.2ms preprocess, 173.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.1ms
# Speed: 1.3ms preprocess, 170.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 160.5ms
# Speed: 1.5ms preprocess, 160.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 176.0ms
# Speed: 1.3ms preprocess, 176.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 156.1ms
# Speed: 1.3ms preprocess, 156.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 190.3ms
# Speed: 1.3ms preprocess, 190.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.4ms
# Speed: 3.6ms preprocess, 168.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.4ms
# Speed: 1.3ms preprocess, 170.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 165.8ms
# Speed: 1.2ms preprocess, 165.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 161.4ms
# Speed: 1.2ms preprocess, 161.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 151.2ms
# Speed: 1.2ms preprocess, 151.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 154.8ms
# Speed: 1.3ms preprocess, 154.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 160.2ms
# Speed: 1.2ms preprocess, 160.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 162.7ms
# Speed: 1.3ms preprocess, 162.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.8ms
# Speed: 1.2ms preprocess, 159.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 155.9ms
# Speed: 1.3ms preprocess, 155.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 162.3ms
# Speed: 1.3ms preprocess, 162.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.7ms
# Speed: 1.3ms preprocess, 159.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 178.9ms
# Speed: 1.3ms preprocess, 178.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.8ms
# Speed: 1.2ms preprocess, 167.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.0ms
# Speed: 1.2ms preprocess, 166.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 184.8ms
# Speed: 1.2ms preprocess, 184.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 193.1ms
# Speed: 1.3ms preprocess, 193.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 198.0ms
# Speed: 1.2ms preprocess, 198.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 161.0ms
# Speed: 1.2ms preprocess, 161.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.8ms
# Speed: 1.7ms preprocess, 164.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 156.3ms
# Speed: 1.3ms preprocess, 156.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 162.8ms
# Speed: 1.5ms preprocess, 162.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 163.9ms
# Speed: 1.4ms preprocess, 163.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.6ms
# Speed: 1.2ms preprocess, 159.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 161.9ms
# Speed: 1.3ms preprocess, 161.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 155.1ms
# Speed: 1.4ms preprocess, 155.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 163.4ms
# Speed: 1.3ms preprocess, 163.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 155.4ms
# Speed: 1.2ms preprocess, 155.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 151.3ms
# Speed: 1.2ms preprocess, 151.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 161.7ms
# Speed: 1.5ms preprocess, 161.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.8ms
# Speed: 1.4ms preprocess, 166.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 182.8ms
# Speed: 1.2ms preprocess, 182.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.2ms
# Speed: 1.3ms preprocess, 175.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 178.7ms
# Speed: 1.4ms preprocess, 178.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 194.7ms
# Speed: 1.8ms preprocess, 194.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.4ms
# Speed: 1.6ms preprocess, 172.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 163.3ms
# Speed: 1.3ms preprocess, 163.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 157.9ms
# Speed: 1.2ms preprocess, 157.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 154.2ms
# Speed: 1.3ms preprocess, 154.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 185.1ms
# Speed: 3.7ms preprocess, 185.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.9ms
# Speed: 1.3ms preprocess, 169.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.3ms
# Speed: 1.3ms preprocess, 159.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 161.2ms
# Speed: 1.3ms preprocess, 161.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 157.9ms
# Speed: 1.2ms preprocess, 157.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 155.6ms
# Speed: 1.4ms preprocess, 155.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 156.4ms
# Speed: 1.4ms preprocess, 156.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 161.8ms
# Speed: 1.4ms preprocess, 161.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 156.6ms
# Speed: 1.2ms preprocess, 156.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 179.6ms
# Speed: 1.4ms preprocess, 179.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.4ms
# Speed: 3.5ms preprocess, 169.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.3ms
# Speed: 1.3ms preprocess, 169.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 195.7ms
# Speed: 1.4ms preprocess, 195.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 188.5ms
# Speed: 1.2ms preprocess, 188.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 158.3ms
# Speed: 1.4ms preprocess, 158.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.3ms
# Speed: 1.2ms preprocess, 173.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 181.5ms
# Speed: 1.6ms preprocess, 181.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.5ms
# Speed: 1.4ms preprocess, 166.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 180.3ms
# Speed: 1.3ms preprocess, 180.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 197.7ms
# Speed: 1.5ms preprocess, 197.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.6ms
# Speed: 1.5ms preprocess, 174.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.2ms
# Speed: 1.3ms preprocess, 164.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 190.9ms
# Speed: 1.3ms preprocess, 190.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.7ms
# Speed: 1.2ms preprocess, 164.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.2ms
# Speed: 1.3ms preprocess, 168.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.0ms
# Speed: 1.3ms preprocess, 173.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 189.7ms
# Speed: 1.3ms preprocess, 189.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.1ms
# Speed: 2.1ms preprocess, 166.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 181.7ms
# Speed: 1.3ms preprocess, 181.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.9ms
# Speed: 1.2ms preprocess, 170.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# /var/folders/zz/y2_h9x0s2378k58hfr7vvwmh0000gn/T/ipykernel_65041/975446659.py:12: RuntimeWarning: invalid value encountered in scalar divide
#   cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
# 0: 384x640 1 person, 195.7ms
# Speed: 1.5ms preprocess, 195.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 177.9ms
# Speed: 1.7ms preprocess, 177.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 162.5ms
# Speed: 1.5ms preprocess, 162.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 176.8ms
# Speed: 1.2ms preprocess, 176.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 163.6ms
# Speed: 1.3ms preprocess, 163.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 162.4ms
# Speed: 1.2ms preprocess, 162.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 163.6ms
# Speed: 1.3ms preprocess, 163.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.2ms
# Speed: 1.2ms preprocess, 169.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.0ms
# Speed: 1.2ms preprocess, 167.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.1ms
# Speed: 1.3ms preprocess, 159.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.9ms
# Speed: 1.4ms preprocess, 169.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.5ms
# Speed: 1.2ms preprocess, 159.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.2ms
# Speed: 1.2ms preprocess, 168.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.4ms
# Speed: 1.2ms preprocess, 167.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 161.8ms
# Speed: 1.2ms preprocess, 161.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.3ms
# Speed: 1.3ms preprocess, 167.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 181.6ms
# Speed: 1.4ms preprocess, 181.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 184.2ms
# Speed: 1.3ms preprocess, 184.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 194.4ms
# Speed: 1.2ms preprocess, 194.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.8ms
# Speed: 1.4ms preprocess, 174.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 182.7ms
# Speed: 1.6ms preprocess, 182.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.3ms
# Speed: 1.2ms preprocess, 174.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.4ms
# Speed: 1.2ms preprocess, 164.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 163.3ms
# Speed: 1.2ms preprocess, 163.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.5ms
# Speed: 1.3ms preprocess, 164.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.5ms
# Speed: 1.2ms preprocess, 169.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 181.4ms
# Speed: 1.3ms preprocess, 181.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 157.6ms
# Speed: 1.2ms preprocess, 157.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 162.8ms
# Speed: 1.4ms preprocess, 162.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.4ms
# Speed: 1.2ms preprocess, 166.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 165.0ms
# Speed: 1.2ms preprocess, 165.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 160.7ms
# Speed: 1.3ms preprocess, 160.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 162.6ms
# Speed: 1.3ms preprocess, 162.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.6ms
# Speed: 1.2ms preprocess, 167.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 180.8ms
# Speed: 1.3ms preprocess, 180.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.1ms
# Speed: 1.4ms preprocess, 171.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 159.7ms
# Speed: 1.2ms preprocess, 159.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 163.1ms
# Speed: 1.3ms preprocess, 163.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.7ms
# Speed: 1.2ms preprocess, 164.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 163.4ms
# Speed: 1.2ms preprocess, 163.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 158.4ms
# Speed: 1.4ms preprocess, 158.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.0ms
# Speed: 1.2ms preprocess, 168.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.1ms
# Speed: 1.3ms preprocess, 168.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 179.2ms
# Speed: 1.4ms preprocess, 179.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.4ms
# Speed: 1.2ms preprocess, 173.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 187.5ms
# Speed: 1.2ms preprocess, 187.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.7ms
# Speed: 4.7ms preprocess, 172.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 185.9ms
# Speed: 1.4ms preprocess, 185.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 165.2ms
# Speed: 1.6ms preprocess, 165.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 175.6ms
# Speed: 1.2ms preprocess, 175.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.6ms
# Speed: 1.6ms preprocess, 169.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.8ms
# Speed: 1.4ms preprocess, 174.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 169.8ms
# Speed: 1.4ms preprocess, 169.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.5ms
# Speed: 1.3ms preprocess, 167.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 178.5ms
# Speed: 1.2ms preprocess, 178.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 174.8ms
# Speed: 1.3ms preprocess, 174.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 164.2ms
# Speed: 1.2ms preprocess, 164.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 181.2ms
# Speed: 1.4ms preprocess, 181.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 166.1ms
# Speed: 1.3ms preprocess, 166.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 165.8ms
# Speed: 1.4ms preprocess, 165.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.9ms
# Speed: 1.4ms preprocess, 168.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 171.0ms
# Speed: 1.3ms preprocess, 171.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 167.2ms
# Speed: 1.2ms preprocess, 167.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.0ms
# Speed: 1.2ms preprocess, 172.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 163.8ms
# Speed: 1.2ms preprocess, 163.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 184.8ms
# Speed: 1.1ms preprocess, 184.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.3ms
# Speed: 1.3ms preprocess, 173.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 172.5ms
# Speed: 1.2ms preprocess, 172.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 185.8ms
# Speed: 1.2ms preprocess, 185.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 186.1ms
# Speed: 1.3ms preprocess, 186.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 162.2ms
# Speed: 1.2ms preprocess, 162.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 168.4ms
# Speed: 1.2ms preprocess, 168.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 170.6ms
# Speed: 1.3ms preprocess, 170.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 173.0ms
# Speed: 1.3ms preprocess, 173.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Done: /Users/shruti.kalaskar/Documents/Northwestern/Spring 2025/Computer Vision/Project/push_up_1_output.mp4
#
# 0: 384x640 2 persons, 213.7ms
# Speed: 1.4ms preprocess, 213.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 175.8ms
# Speed: 1.7ms preprocess, 175.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 178.7ms
# Speed: 1.3ms preprocess, 178.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 194.0ms
# Speed: 1.6ms preprocess, 194.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 176.9ms
# Speed: 1.8ms preprocess, 176.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 180.1ms
# Speed: 1.2ms preprocess, 180.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 188.4ms
# Speed: 1.9ms preprocess, 188.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.5ms
# Speed: 1.2ms preprocess, 159.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.0ms
# Speed: 1.2ms preprocess, 161.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.7ms
# Speed: 1.5ms preprocess, 165.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 162.1ms
# Speed: 1.2ms preprocess, 162.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.8ms
# Speed: 1.1ms preprocess, 159.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.6ms
# Speed: 1.3ms preprocess, 164.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.3ms
# Speed: 1.5ms preprocess, 165.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.9ms
# Speed: 1.2ms preprocess, 164.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 163.9ms
# Speed: 1.4ms preprocess, 163.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.6ms
# Speed: 1.1ms preprocess, 165.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.5ms
# Speed: 1.4ms preprocess, 167.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.5ms
# Speed: 1.1ms preprocess, 166.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 163.4ms
# Speed: 1.2ms preprocess, 163.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.0ms
# Speed: 1.3ms preprocess, 164.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.3ms
# Speed: 1.2ms preprocess, 164.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.3ms
# Speed: 1.2ms preprocess, 164.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.3ms
# Speed: 1.1ms preprocess, 161.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 162.5ms
# Speed: 1.3ms preprocess, 162.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.0ms
# Speed: 1.3ms preprocess, 164.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.1ms
# Speed: 1.2ms preprocess, 160.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.2ms
# Speed: 1.2ms preprocess, 166.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.6ms
# Speed: 1.2ms preprocess, 166.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.8ms
# Speed: 1.2ms preprocess, 161.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 163.3ms
# Speed: 1.2ms preprocess, 163.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.4ms
# Speed: 1.2ms preprocess, 159.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.9ms
# Speed: 1.2ms preprocess, 166.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 163.7ms
# Speed: 1.3ms preprocess, 163.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.1ms
# Speed: 1.3ms preprocess, 166.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.2ms
# Speed: 1.4ms preprocess, 164.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.4ms
# Speed: 1.2ms preprocess, 165.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.9ms
# Speed: 1.3ms preprocess, 160.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.2ms
# Speed: 1.4ms preprocess, 165.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 163.9ms
# Speed: 1.2ms preprocess, 163.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.7ms
# Speed: 1.4ms preprocess, 159.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.0ms
# Speed: 1.2ms preprocess, 160.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.8ms
# Speed: 1.4ms preprocess, 159.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 169.7ms
# Speed: 1.2ms preprocess, 169.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.1ms
# Speed: 1.2ms preprocess, 167.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.9ms
# Speed: 1.2ms preprocess, 168.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.6ms
# Speed: 1.3ms preprocess, 167.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 169.8ms
# Speed: 1.3ms preprocess, 169.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.2ms
# Speed: 1.2ms preprocess, 161.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 162.3ms
# Speed: 1.3ms preprocess, 162.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 162.0ms
# Speed: 1.3ms preprocess, 162.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 178.5ms
# Speed: 1.3ms preprocess, 178.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.6ms
# Speed: 1.4ms preprocess, 166.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.1ms
# Speed: 1.2ms preprocess, 168.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.2ms
# Speed: 1.2ms preprocess, 165.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.0ms
# Speed: 1.5ms preprocess, 161.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.4ms
# Speed: 1.3ms preprocess, 167.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.2ms
# Speed: 1.3ms preprocess, 168.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.9ms
# Speed: 1.3ms preprocess, 168.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 190.7ms
# Speed: 1.4ms preprocess, 190.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 176.3ms
# Speed: 1.4ms preprocess, 176.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 221.8ms
# Speed: 1.2ms preprocess, 221.8ms inference, 7.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 235.2ms
# Speed: 1.6ms preprocess, 235.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.1ms
# Speed: 1.3ms preprocess, 164.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.8ms
# Speed: 1.3ms preprocess, 165.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 155.3ms
# Speed: 1.2ms preprocess, 155.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.1ms
# Speed: 1.2ms preprocess, 165.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 162.3ms
# Speed: 1.3ms preprocess, 162.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 174.5ms
# Speed: 1.4ms preprocess, 174.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.1ms
# Speed: 1.3ms preprocess, 161.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 197.2ms
# Speed: 1.2ms preprocess, 197.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 179.7ms
# Speed: 1.2ms preprocess, 179.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 181.6ms
# Speed: 1.4ms preprocess, 181.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 187.3ms
# Speed: 1.2ms preprocess, 187.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 175.0ms
# Speed: 1.2ms preprocess, 175.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 193.4ms
# Speed: 1.4ms preprocess, 193.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 157.5ms
# Speed: 1.2ms preprocess, 157.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 208.3ms
# Speed: 1.9ms preprocess, 208.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.9ms
# Speed: 1.3ms preprocess, 165.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.0ms
# Speed: 1.3ms preprocess, 158.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.3ms
# Speed: 1.2ms preprocess, 164.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 157.1ms
# Speed: 1.3ms preprocess, 157.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 155.2ms
# Speed: 1.5ms preprocess, 155.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.6ms
# Speed: 1.3ms preprocess, 159.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.8ms
# Speed: 1.2ms preprocess, 158.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 157.1ms
# Speed: 1.2ms preprocess, 157.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 235.5ms
# Speed: 1.2ms preprocess, 235.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.9ms
# Speed: 1.2ms preprocess, 159.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.0ms
# Speed: 1.4ms preprocess, 166.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.0ms
# Speed: 1.2ms preprocess, 164.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.9ms
# Speed: 1.3ms preprocess, 154.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.4ms
# Speed: 1.2ms preprocess, 158.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.4ms
# Speed: 1.4ms preprocess, 160.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.8ms
# Speed: 1.4ms preprocess, 158.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.0ms
# Speed: 1.4ms preprocess, 165.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 198.3ms
# Speed: 1.2ms preprocess, 198.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 156.8ms
# Speed: 1.6ms preprocess, 156.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 216.5ms
# Speed: 1.2ms preprocess, 216.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.2ms
# Speed: 1.2ms preprocess, 158.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.2ms
# Speed: 1.3ms preprocess, 160.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.0ms
# Speed: 1.3ms preprocess, 161.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.9ms
# Speed: 1.3ms preprocess, 158.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.1ms
# Speed: 1.2ms preprocess, 159.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.9ms
# Speed: 1.6ms preprocess, 165.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 200.4ms
# Speed: 1.3ms preprocess, 200.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 161.9ms
# Speed: 1.4ms preprocess, 161.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 186.6ms
# Speed: 1.2ms preprocess, 186.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 184.6ms
# Speed: 2.5ms preprocess, 184.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 204.9ms
# Speed: 1.7ms preprocess, 204.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.1ms
# Speed: 1.3ms preprocess, 165.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.1ms
# Speed: 1.2ms preprocess, 160.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 171.5ms
# Speed: 1.3ms preprocess, 171.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.8ms
# Speed: 1.2ms preprocess, 160.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.5ms
# Speed: 1.2ms preprocess, 160.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 172.2ms
# Speed: 1.2ms preprocess, 172.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.8ms
# Speed: 1.2ms preprocess, 165.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.6ms
# Speed: 1.2ms preprocess, 160.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.4ms
# Speed: 1.2ms preprocess, 159.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 154.4ms
# Speed: 1.4ms preprocess, 154.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.0ms
# Speed: 1.4ms preprocess, 158.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.2ms
# Speed: 1.3ms preprocess, 160.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 169.1ms
# Speed: 1.2ms preprocess, 169.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 170.9ms
# Speed: 1.2ms preprocess, 170.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 169.7ms
# Speed: 3.7ms preprocess, 169.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 158.5ms
# Speed: 1.3ms preprocess, 158.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 229.7ms
# Speed: 1.7ms preprocess, 229.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 171.2ms
# Speed: 1.5ms preprocess, 171.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 170.0ms
# Speed: 1.5ms preprocess, 170.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.7ms
# Speed: 1.2ms preprocess, 164.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 159.6ms
# Speed: 1.6ms preprocess, 159.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.0ms
# Speed: 1.3ms preprocess, 167.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.0ms
# Speed: 1.3ms preprocess, 168.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.9ms
# Speed: 1.2ms preprocess, 167.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.5ms
# Speed: 1.4ms preprocess, 160.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 168.9ms
# Speed: 1.2ms preprocess, 168.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.0ms
# Speed: 1.2ms preprocess, 165.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 173.1ms
# Speed: 1.2ms preprocess, 173.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 170.2ms
# Speed: 1.2ms preprocess, 170.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.1ms
# Speed: 1.3ms preprocess, 167.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 164.2ms
# Speed: 1.3ms preprocess, 164.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.2ms
# Speed: 1.2ms preprocess, 165.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.9ms
# Speed: 1.2ms preprocess, 160.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 178.0ms
# Speed: 1.2ms preprocess, 178.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 160.7ms
# Speed: 1.2ms preprocess, 160.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.9ms
# Speed: 1.3ms preprocess, 167.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 162.2ms
# Speed: 1.2ms preprocess, 162.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 167.6ms
# Speed: 1.2ms preprocess, 167.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.3ms
# Speed: 1.4ms preprocess, 165.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 166.4ms
# Speed: 1.2ms preprocess, 166.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 165.8ms
# Speed: 1.2ms preprocess, 165.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Done: /Users/shruti.kalaskar/Documents/Northwestern/Spring 2025/Computer Vision/Project/push_up_2_output.mp4
