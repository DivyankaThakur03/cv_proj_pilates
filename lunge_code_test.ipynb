# %%
import cv2
import numpy as np
from ultralytics import YOLO
from collections import deque
import math
import os

def add_summary_frame(video_writer, width, height, exercise_name, count):
    calories_per_rep = {'pushup': 0.5, 'lunge': 0.3}
    cal_burned = round(count * calories_per_rep.get(exercise_name.lower(), 0.4), 2)

    summary_frame = np.zeros((height, width, 3), dtype=np.uint8)
    summary_frame[:] = (30, 30, 30)

    font = cv2.FONT_HERSHEY_SIMPLEX
    x = int(width * 0.08)
    y_start = int(height * 0.25)
    spacing = 35

    cv2.putText(summary_frame, "Workout Summary", (x, y_start), font, 0.9, (255, 255, 255), 2)
    cv2.putText(summary_frame, f"Exercise: {exercise_name}", (x, y_start + spacing * 2), font, 0.6, (180, 200, 255), 1)
    cv2.putText(summary_frame, f"Reps: {count}", (x, y_start + spacing * 3), font, 0.6, (200, 255, 200), 1)
    cv2.putText(summary_frame, f"Estimated Calories: {cal_burned} kcal", (x, y_start + spacing * 4), font, 0.6, (255, 220, 200), 1)

    for _ in range(60):
        video_writer.write(summary_frame)

class DebugLungeCounter:
    def __init__(self, model_name='yolo11s-pose.pt'):
        self.model = YOLO(model_name)
        self.lunge_count = 0
        self.lunge_stage = "up"
        self.confidence_threshold = 0.3
        self.knee_down_threshold = 135
        self.knee_up_threshold = 155
        self.knee_angles_history = deque(maxlen=5)
        self.frame_count = 0

    def detect_pose_yolo11(self, frame):
        results = self.model(frame)
        if results[0].keypoints is not None and len(results[0].keypoints.xy) > 0:
            keypoints = results[0].keypoints.xy[0].cpu().numpy()
            confidences = results[0].keypoints.conf[0].cpu().numpy() if results[0].keypoints.conf is not None else None
            return keypoints, confidences, results[0]
        return None, None, results[0]

    def calculate_angle(self, point1, point2, point3):
        try:
            a, b, c = np.array(point1), np.array(point2), np.array(point3)
            ba, bc = a - b, c - b
            cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
            angle = np.arccos(np.clip(cosine_angle, -1.0, 1.0))
            return np.degrees(angle)
        except:
            return 180

    def get_knee_angles(self, keypoints, confidences):
        if keypoints is None or len(keypoints) < 17:
            return None, None, None, None
        left_hip, left_knee, left_ankle = keypoints[11], keypoints[13], keypoints[15]
        right_hip, right_knee, right_ankle = keypoints[12], keypoints[14], keypoints[16]
        left_conf = min(confidences[11], confidences[13], confidences[15]) if confidences is not None else 1.0
        right_conf = min(confidences[12], confidences[14], confidences[16]) if confidences is not None else 1.0
        left_angle = self.calculate_angle(left_hip, left_knee, left_ankle) if left_conf > self.confidence_threshold else None
        right_angle = self.calculate_angle(right_hip, right_knee, right_ankle) if right_conf > self.confidence_threshold else None
        return left_angle, right_angle, left_conf, right_conf

    def update_lunge_count(self, left_angle, right_angle):
        working_angle = left_angle if right_angle is None else right_angle if left_angle is None else min(left_angle, right_angle)
        if working_angle is None:
            return False
        self.knee_angles_history.append(working_angle)
        smoothed_angle = np.mean(self.knee_angles_history) if len(self.knee_angles_history) >= 3 else working_angle
        lunge_detected = False
        if smoothed_angle < self.knee_down_threshold and self.lunge_stage == "up":
            self.lunge_stage = "down"
        elif smoothed_angle > self.knee_up_threshold and self.lunge_stage == "down":
            self.lunge_stage = "up"
            self.lunge_count += 1
            lunge_detected = True
        return lunge_detected

    def get_count(self):
        return self.lunge_count

def process_debug_lunge_video(video_path, model_name='yolo11s-pose.pt', output_path="lunge_output_horizontal.mp4"):
    counter = DebugLungeCounter(model_name=model_name)
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}")
        return None

    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'mp4v'), fps, (width, height))

    for _ in range(total_frames):
        ret, frame = cap.read()
        if not ret:
            break

        counter.frame_count += 1
        keypoints, confidences, results = counter.detect_pose_yolo11(frame)
        if keypoints is not None:
            frame = results.plot()

        left_angle, right_angle, _, _ = counter.get_knee_angles(keypoints, confidences)
        counter.update_lunge_count(left_angle, right_angle)

        cv2.putText(frame, f"LUNGES: {counter.get_count()}", (20, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (202, 255, 150), 2)
        cv2.putText(frame, f"XP: {counter.get_count() * 10}", (20, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (255, 150, 50), 2)

        out.write(frame)

    add_summary_frame(out, width, height, "Lunge", counter.get_count())
    cap.release()
    out.release()
    print(f"Output saved: {output_path}")
    return output_path, counter.get_count()

if __name__ == "__main__":
    VIDEO_DIR = "/Users/shruti.kalaskar/Documents/Northwestern/Spring 2025/Computer Vision/Project/"
    MODEL_NAME = 'yolo11s-pose.pt'
    video_files = ["lunge_reformer_1.mp4", "lunge_reformer_2.mp4"]
    for video_file in video_files:
        input_path = os.path.join(VIDEO_DIR, video_file)
        output_path = os.path.join(VIDEO_DIR, video_file.replace(".mp4", "_output.mp4"))
        if os.path.exists(input_path):
            print(f"\\n▶️ Processing video: {input_path}")
            process_debug_lunge_video(video_path=input_path, model_name=MODEL_NAME, output_path=output_path)
        else:
            print(f"File not found: {input_path}")
# Out:
# \n▶️ Processing video: /Users/shruti.kalaskar/Documents/Northwestern/Spring 2025/Computer Vision/Project/lunge_reformer_1.mp4
#
# 0: 640x384 1 person, 344.2ms
# Speed: 2.5ms preprocess, 344.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# [W NNPACK.cpp:64] Could not initialize NNPACK! Reason: Unsupported hardware.
# 0: 640x384 1 person, 190.1ms
# Speed: 0.9ms preprocess, 190.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.8ms
# Speed: 0.9ms preprocess, 166.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.2ms
# Speed: 0.8ms preprocess, 163.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.0ms
# Speed: 0.7ms preprocess, 162.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.7ms
# Speed: 0.8ms preprocess, 162.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.4ms
# Speed: 0.8ms preprocess, 163.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.7ms
# Speed: 0.8ms preprocess, 161.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.2ms
# Speed: 0.7ms preprocess, 175.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.5ms
# Speed: 0.8ms preprocess, 169.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 173.8ms
# Speed: 0.8ms preprocess, 173.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 154.3ms
# Speed: 0.7ms preprocess, 154.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 202.4ms
# Speed: 0.7ms preprocess, 202.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 177.7ms
# Speed: 1.1ms preprocess, 177.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 187.7ms
# Speed: 0.9ms preprocess, 187.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.3ms
# Speed: 1.1ms preprocess, 166.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.5ms
# Speed: 0.7ms preprocess, 164.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.4ms
# Speed: 0.8ms preprocess, 169.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.7ms
# Speed: 0.8ms preprocess, 167.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.4ms
# Speed: 0.8ms preprocess, 163.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.3ms
# Speed: 0.7ms preprocess, 164.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.2ms
# Speed: 0.8ms preprocess, 162.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.5ms
# Speed: 0.8ms preprocess, 163.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.1ms
# Speed: 0.8ms preprocess, 167.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.8ms
# Speed: 0.8ms preprocess, 168.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.5ms
# Speed: 6.3ms preprocess, 168.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.9ms
# Speed: 0.9ms preprocess, 160.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.9ms
# Speed: 0.9ms preprocess, 164.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.8ms
# Speed: 0.7ms preprocess, 162.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.7ms
# Speed: 0.7ms preprocess, 164.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 185.6ms
# Speed: 0.9ms preprocess, 185.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 183.0ms
# Speed: 0.9ms preprocess, 183.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 173.5ms
# Speed: 0.8ms preprocess, 173.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.1ms
# Speed: 1.2ms preprocess, 164.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.7ms
# Speed: 0.8ms preprocess, 166.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.3ms
# Speed: 0.9ms preprocess, 163.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.2ms
# Speed: 0.8ms preprocess, 165.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.6ms
# Speed: 0.8ms preprocess, 160.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.4ms
# Speed: 0.9ms preprocess, 155.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.9ms
# Speed: 0.8ms preprocess, 164.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.4ms
# Speed: 0.9ms preprocess, 164.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.9ms
# Speed: 1.0ms preprocess, 161.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.6ms
# Speed: 0.9ms preprocess, 165.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.0ms
# Speed: 0.8ms preprocess, 167.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.6ms
# Speed: 0.6ms preprocess, 164.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.3ms
# Speed: 0.8ms preprocess, 168.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.3ms
# Speed: 0.8ms preprocess, 163.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.2ms
# Speed: 0.9ms preprocess, 161.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.8ms
# Speed: 0.8ms preprocess, 167.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.0ms
# Speed: 0.7ms preprocess, 165.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.3ms
# Speed: 1.2ms preprocess, 164.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.3ms
# Speed: 0.8ms preprocess, 161.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.2ms
# Speed: 0.7ms preprocess, 164.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.6ms
# Speed: 0.9ms preprocess, 164.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.2ms
# Speed: 4.0ms preprocess, 171.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.7ms
# Speed: 0.9ms preprocess, 165.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.0ms
# Speed: 0.9ms preprocess, 167.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.5ms
# Speed: 0.9ms preprocess, 162.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.1ms
# Speed: 0.9ms preprocess, 166.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.1ms
# Speed: 0.7ms preprocess, 159.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.0ms
# Speed: 0.9ms preprocess, 159.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 177.0ms
# Speed: 0.7ms preprocess, 177.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 193.1ms
# Speed: 0.8ms preprocess, 193.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.0ms
# Speed: 1.0ms preprocess, 168.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.5ms
# Speed: 0.8ms preprocess, 166.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.5ms
# Speed: 0.7ms preprocess, 165.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 195.7ms
# Speed: 0.8ms preprocess, 195.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.4ms
# Speed: 0.8ms preprocess, 166.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.0ms
# Speed: 0.8ms preprocess, 161.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.8ms
# Speed: 1.0ms preprocess, 169.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.6ms
# Speed: 0.8ms preprocess, 160.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.2ms
# Speed: 0.8ms preprocess, 165.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.5ms
# Speed: 1.1ms preprocess, 160.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 187.8ms
# Speed: 0.8ms preprocess, 187.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.7ms
# Speed: 0.8ms preprocess, 163.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.2ms
# Speed: 0.8ms preprocess, 163.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.9ms
# Speed: 1.0ms preprocess, 169.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.5ms
# Speed: 0.9ms preprocess, 161.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.1ms
# Speed: 0.8ms preprocess, 161.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.3ms
# Speed: 0.9ms preprocess, 162.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.0ms
# Speed: 0.7ms preprocess, 166.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.4ms
# Speed: 0.7ms preprocess, 166.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.1ms
# Speed: 0.9ms preprocess, 164.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.7ms
# Speed: 0.9ms preprocess, 161.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.4ms
# Speed: 1.1ms preprocess, 171.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.2ms
# Speed: 0.8ms preprocess, 163.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 191.1ms
# Speed: 0.8ms preprocess, 191.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.8ms
# Speed: 0.8ms preprocess, 166.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.9ms
# Speed: 0.9ms preprocess, 169.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 201.3ms
# Speed: 0.7ms preprocess, 201.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 223.9ms
# Speed: 1.1ms preprocess, 223.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 212.4ms
# Speed: 1.0ms preprocess, 212.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 174.6ms
# Speed: 0.9ms preprocess, 174.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 196.7ms
# Speed: 0.7ms preprocess, 196.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.0ms
# Speed: 2.1ms preprocess, 168.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.0ms
# Speed: 0.9ms preprocess, 158.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.7ms
# Speed: 0.8ms preprocess, 158.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.8ms
# Speed: 0.8ms preprocess, 156.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.8ms
# Speed: 0.9ms preprocess, 161.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.0ms
# Speed: 0.8ms preprocess, 158.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.1ms
# Speed: 0.9ms preprocess, 155.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.5ms
# Speed: 0.7ms preprocess, 156.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.3ms
# Speed: 0.9ms preprocess, 155.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.8ms
# Speed: 0.8ms preprocess, 157.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.9ms
# Speed: 0.9ms preprocess, 165.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 206.3ms
# Speed: 0.7ms preprocess, 206.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.0ms
# Speed: 0.9ms preprocess, 161.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.5ms
# Speed: 0.8ms preprocess, 162.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.9ms
# Speed: 0.9ms preprocess, 161.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 207.3ms
# Speed: 0.8ms preprocess, 207.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 190.9ms
# Speed: 0.8ms preprocess, 190.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 193.9ms
# Speed: 1.0ms preprocess, 193.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 225.1ms
# Speed: 0.9ms preprocess, 225.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 203.6ms
# Speed: 0.9ms preprocess, 203.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.5ms
# Speed: 1.2ms preprocess, 175.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.4ms
# Speed: 1.0ms preprocess, 163.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 153.2ms
# Speed: 0.9ms preprocess, 153.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.8ms
# Speed: 0.8ms preprocess, 159.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.1ms
# Speed: 0.9ms preprocess, 157.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.9ms
# Speed: 1.0ms preprocess, 155.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.2ms
# Speed: 1.1ms preprocess, 162.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.9ms
# Speed: 0.8ms preprocess, 159.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.8ms
# Speed: 1.0ms preprocess, 175.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.3ms
# Speed: 0.8ms preprocess, 158.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.7ms
# Speed: 0.9ms preprocess, 162.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.0ms
# Speed: 0.9ms preprocess, 161.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.4ms
# Speed: 0.9ms preprocess, 161.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.4ms
# Speed: 0.8ms preprocess, 155.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.7ms
# Speed: 0.9ms preprocess, 161.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.2ms
# Speed: 0.8ms preprocess, 155.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.4ms
# Speed: 0.8ms preprocess, 160.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.1ms
# Speed: 0.9ms preprocess, 157.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 153.4ms
# Speed: 0.9ms preprocess, 153.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 203.0ms
# Speed: 0.9ms preprocess, 203.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.6ms
# Speed: 0.9ms preprocess, 155.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.2ms
# Speed: 0.9ms preprocess, 158.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.2ms
# Speed: 0.8ms preprocess, 159.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 152.6ms
# Speed: 0.9ms preprocess, 152.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.0ms
# Speed: 0.8ms preprocess, 160.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.8ms
# Speed: 0.9ms preprocess, 161.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.7ms
# Speed: 0.8ms preprocess, 160.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.8ms
# Speed: 0.9ms preprocess, 160.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 154.3ms
# Speed: 0.8ms preprocess, 154.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.4ms
# Speed: 0.9ms preprocess, 159.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.9ms
# Speed: 1.0ms preprocess, 160.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.1ms
# Speed: 0.9ms preprocess, 155.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.5ms
# Speed: 0.8ms preprocess, 161.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.4ms
# Speed: 1.1ms preprocess, 158.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.1ms
# Speed: 0.9ms preprocess, 163.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.6ms
# Speed: 0.8ms preprocess, 157.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 200.0ms
# Speed: 0.9ms preprocess, 200.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.8ms
# Speed: 0.8ms preprocess, 161.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 200.3ms
# Speed: 1.2ms preprocess, 200.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.9ms
# Speed: 0.8ms preprocess, 161.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.1ms
# Speed: 1.0ms preprocess, 167.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 191.8ms
# Speed: 1.5ms preprocess, 191.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.3ms
# Speed: 0.9ms preprocess, 155.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 184.9ms
# Speed: 0.9ms preprocess, 184.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 154.7ms
# Speed: 0.9ms preprocess, 154.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.6ms
# Speed: 0.8ms preprocess, 166.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.5ms
# Speed: 0.8ms preprocess, 157.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.1ms
# Speed: 0.8ms preprocess, 158.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.4ms
# Speed: 0.7ms preprocess, 161.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.0ms
# Speed: 0.9ms preprocess, 161.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.4ms
# Speed: 1.0ms preprocess, 159.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.7ms
# Speed: 0.7ms preprocess, 161.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.0ms
# Speed: 0.8ms preprocess, 157.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.6ms
# Speed: 1.3ms preprocess, 160.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 179.9ms
# Speed: 0.8ms preprocess, 179.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.9ms
# Speed: 0.8ms preprocess, 158.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.4ms
# Speed: 1.5ms preprocess, 165.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.1ms
# Speed: 0.9ms preprocess, 157.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.5ms
# Speed: 1.0ms preprocess, 157.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.2ms
# Speed: 0.7ms preprocess, 159.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.0ms
# Speed: 0.9ms preprocess, 160.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.0ms
# Speed: 0.7ms preprocess, 159.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.6ms
# Speed: 0.9ms preprocess, 160.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.6ms
# Speed: 1.0ms preprocess, 158.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.4ms
# Speed: 1.0ms preprocess, 156.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.4ms
# Speed: 0.8ms preprocess, 159.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.9ms
# Speed: 0.9ms preprocess, 156.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.8ms
# Speed: 0.8ms preprocess, 156.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.9ms
# Speed: 1.0ms preprocess, 158.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.2ms
# Speed: 1.0ms preprocess, 158.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 181.0ms
# Speed: 0.7ms preprocess, 181.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.2ms
# Speed: 0.8ms preprocess, 160.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.4ms
# Speed: 0.8ms preprocess, 160.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.0ms
# Speed: 0.9ms preprocess, 158.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.7ms
# Speed: 0.8ms preprocess, 155.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.6ms
# Speed: 0.8ms preprocess, 160.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.7ms
# Speed: 0.8ms preprocess, 157.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.8ms
# Speed: 1.0ms preprocess, 155.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.2ms
# Speed: 0.8ms preprocess, 160.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.2ms
# Speed: 1.1ms preprocess, 160.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.8ms
# Speed: 0.9ms preprocess, 159.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 179.9ms
# Speed: 0.8ms preprocess, 179.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.8ms
# Speed: 0.7ms preprocess, 157.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.6ms
# Speed: 0.8ms preprocess, 162.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.9ms
# Speed: 0.9ms preprocess, 161.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 154.4ms
# Speed: 0.9ms preprocess, 154.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.8ms
# Speed: 0.8ms preprocess, 156.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.1ms
# Speed: 0.7ms preprocess, 158.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 176.8ms
# Speed: 0.8ms preprocess, 176.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.9ms
# Speed: 1.0ms preprocess, 168.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.2ms
# Speed: 1.2ms preprocess, 156.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.4ms
# Speed: 0.8ms preprocess, 165.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.2ms
# Speed: 1.0ms preprocess, 155.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.8ms
# Speed: 0.9ms preprocess, 160.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 205.0ms
# Speed: 0.9ms preprocess, 205.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 240.2ms
# Speed: 0.8ms preprocess, 240.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.8ms
# Speed: 0.8ms preprocess, 164.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.6ms
# Speed: 0.9ms preprocess, 159.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.4ms
# Speed: 0.8ms preprocess, 164.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.0ms
# Speed: 0.9ms preprocess, 160.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 154.0ms
# Speed: 0.8ms preprocess, 154.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.6ms
# Speed: 0.9ms preprocess, 161.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.0ms
# Speed: 0.9ms preprocess, 158.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.7ms
# Speed: 0.8ms preprocess, 157.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.2ms
# Speed: 0.8ms preprocess, 158.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.7ms
# Speed: 0.8ms preprocess, 165.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 250.0ms
# Speed: 0.8ms preprocess, 250.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.3ms
# Speed: 0.9ms preprocess, 159.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.9ms
# Speed: 0.8ms preprocess, 164.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.0ms
# Speed: 1.0ms preprocess, 163.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.7ms
# Speed: 1.0ms preprocess, 161.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.1ms
# Speed: 0.8ms preprocess, 160.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 154.6ms
# Speed: 0.8ms preprocess, 154.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.5ms
# Speed: 1.1ms preprocess, 159.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.4ms
# Speed: 0.7ms preprocess, 159.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 154.0ms
# Speed: 0.7ms preprocess, 154.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.9ms
# Speed: 0.7ms preprocess, 155.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.6ms
# Speed: 0.9ms preprocess, 160.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.3ms
# Speed: 0.9ms preprocess, 157.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.2ms
# Speed: 0.8ms preprocess, 159.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 185.9ms
# Speed: 1.2ms preprocess, 185.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.6ms
# Speed: 0.9ms preprocess, 170.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.7ms
# Speed: 0.9ms preprocess, 156.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.4ms
# Speed: 0.9ms preprocess, 170.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.1ms
# Speed: 0.8ms preprocess, 161.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.5ms
# Speed: 0.9ms preprocess, 160.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.8ms
# Speed: 0.8ms preprocess, 159.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.7ms
# Speed: 0.8ms preprocess, 157.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.1ms
# Speed: 0.8ms preprocess, 157.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.4ms
# Speed: 0.9ms preprocess, 156.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.2ms
# Speed: 1.0ms preprocess, 159.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 153.1ms
# Speed: 0.9ms preprocess, 153.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.8ms
# Speed: 0.8ms preprocess, 163.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.4ms
# Speed: 0.9ms preprocess, 166.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.6ms
# Speed: 0.8ms preprocess, 158.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.9ms
# Speed: 0.8ms preprocess, 159.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.2ms
# Speed: 0.8ms preprocess, 156.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 154.7ms
# Speed: 0.9ms preprocess, 154.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.9ms
# Speed: 0.8ms preprocess, 156.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.1ms
# Speed: 0.7ms preprocess, 157.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.9ms
# Speed: 0.7ms preprocess, 157.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.5ms
# Speed: 1.0ms preprocess, 159.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.6ms
# Speed: 0.8ms preprocess, 160.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.9ms
# Speed: 0.8ms preprocess, 160.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.9ms
# Speed: 0.8ms preprocess, 157.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 179.8ms
# Speed: 1.1ms preprocess, 179.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.7ms
# Speed: 0.7ms preprocess, 156.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.0ms
# Speed: 0.7ms preprocess, 158.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.6ms
# Speed: 0.8ms preprocess, 162.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.4ms
# Speed: 0.8ms preprocess, 159.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.1ms
# Speed: 1.1ms preprocess, 156.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.3ms
# Speed: 0.8ms preprocess, 161.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 154.2ms
# Speed: 0.8ms preprocess, 154.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.0ms
# Speed: 0.7ms preprocess, 160.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.7ms
# Speed: 0.9ms preprocess, 161.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.5ms
# Speed: 0.8ms preprocess, 161.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 153.4ms
# Speed: 0.8ms preprocess, 153.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.0ms
# Speed: 0.9ms preprocess, 155.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 152.5ms
# Speed: 0.9ms preprocess, 152.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.3ms
# Speed: 0.9ms preprocess, 162.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.9ms
# Speed: 0.7ms preprocess, 162.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.9ms
# Speed: 0.8ms preprocess, 156.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.5ms
# Speed: 0.8ms preprocess, 158.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.9ms
# Speed: 0.8ms preprocess, 155.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 153.0ms
# Speed: 1.0ms preprocess, 153.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.1ms
# Speed: 1.1ms preprocess, 158.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.9ms
# Speed: 0.9ms preprocess, 156.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.0ms
# Speed: 0.9ms preprocess, 162.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.2ms
# Speed: 1.1ms preprocess, 157.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.3ms
# Speed: 1.0ms preprocess, 161.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 185.0ms
# Speed: 0.8ms preprocess, 185.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.3ms
# Speed: 0.8ms preprocess, 160.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.7ms
# Speed: 0.8ms preprocess, 161.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.7ms
# Speed: 1.0ms preprocess, 158.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.3ms
# Speed: 0.9ms preprocess, 157.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 152.6ms
# Speed: 0.9ms preprocess, 152.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 178.0ms
# Speed: 0.9ms preprocess, 178.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.3ms
# Speed: 1.0ms preprocess, 171.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.5ms
# Speed: 0.7ms preprocess, 159.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.8ms
# Speed: 0.8ms preprocess, 161.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.5ms
# Speed: 0.9ms preprocess, 161.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.8ms
# Speed: 0.7ms preprocess, 157.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.7ms
# Speed: 0.8ms preprocess, 156.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.7ms
# Speed: 0.9ms preprocess, 155.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.8ms
# Speed: 0.8ms preprocess, 162.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 151.2ms
# Speed: 0.9ms preprocess, 151.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.9ms
# Speed: 0.8ms preprocess, 157.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.5ms
# Speed: 0.8ms preprocess, 162.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 154.9ms
# Speed: 0.8ms preprocess, 154.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.3ms
# Speed: 0.8ms preprocess, 159.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.1ms
# Speed: 0.9ms preprocess, 157.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.6ms
# Speed: 0.8ms preprocess, 157.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.6ms
# Speed: 0.9ms preprocess, 163.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.5ms
# Speed: 0.9ms preprocess, 158.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.2ms
# Speed: 0.7ms preprocess, 164.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 184.1ms
# Speed: 0.9ms preprocess, 184.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.8ms
# Speed: 0.9ms preprocess, 155.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.3ms
# Speed: 0.8ms preprocess, 163.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.7ms
# Speed: 1.1ms preprocess, 157.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.3ms
# Speed: 0.9ms preprocess, 157.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.1ms
# Speed: 0.9ms preprocess, 158.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.8ms
# Speed: 0.8ms preprocess, 156.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.6ms
# Speed: 0.8ms preprocess, 156.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.3ms
# Speed: 0.9ms preprocess, 159.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.2ms
# Speed: 1.3ms preprocess, 161.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.5ms
# Speed: 0.9ms preprocess, 163.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.9ms
# Speed: 0.7ms preprocess, 158.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.0ms
# Speed: 0.8ms preprocess, 159.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.3ms
# Speed: 0.8ms preprocess, 156.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.3ms
# Speed: 0.8ms preprocess, 164.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.1ms
# Speed: 2.0ms preprocess, 159.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.7ms
# Speed: 1.0ms preprocess, 159.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.3ms
# Speed: 0.8ms preprocess, 155.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.9ms
# Speed: 0.8ms preprocess, 156.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 154.9ms
# Speed: 0.9ms preprocess, 154.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.8ms
# Speed: 0.8ms preprocess, 159.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.0ms
# Speed: 0.8ms preprocess, 157.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.3ms
# Speed: 1.0ms preprocess, 159.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.6ms
# Speed: 0.8ms preprocess, 155.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 172.5ms
# Speed: 0.7ms preprocess, 172.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 181.2ms
# Speed: 0.8ms preprocess, 181.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.8ms
# Speed: 0.8ms preprocess, 158.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.9ms
# Speed: 0.9ms preprocess, 158.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.6ms
# Speed: 1.0ms preprocess, 159.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.1ms
# Speed: 0.9ms preprocess, 159.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.0ms
# Speed: 0.8ms preprocess, 158.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.0ms
# Speed: 0.8ms preprocess, 159.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.1ms
# Speed: 1.0ms preprocess, 162.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.3ms
# Speed: 0.8ms preprocess, 159.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.1ms
# Speed: 0.7ms preprocess, 158.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.1ms
# Speed: 0.9ms preprocess, 160.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.2ms
# Speed: 0.8ms preprocess, 164.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.7ms
# Speed: 0.9ms preprocess, 155.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.8ms
# Speed: 0.8ms preprocess, 159.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.8ms
# Speed: 1.2ms preprocess, 155.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.3ms
# Speed: 0.8ms preprocess, 160.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.0ms
# Speed: 0.8ms preprocess, 161.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.4ms
# Speed: 1.0ms preprocess, 160.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.3ms
# Speed: 0.9ms preprocess, 155.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.1ms
# Speed: 0.8ms preprocess, 156.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.0ms
# Speed: 0.8ms preprocess, 163.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.5ms
# Speed: 0.8ms preprocess, 159.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.0ms
# Speed: 0.8ms preprocess, 158.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.9ms
# Speed: 0.9ms preprocess, 159.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.2ms
# Speed: 0.8ms preprocess, 155.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 184.4ms
# Speed: 0.9ms preprocess, 184.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 157.6ms
# Speed: 1.0ms preprocess, 157.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.6ms
# Speed: 0.9ms preprocess, 164.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.3ms
# Speed: 0.8ms preprocess, 158.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.9ms
# Speed: 0.8ms preprocess, 161.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.0ms
# Speed: 0.8ms preprocess, 156.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.2ms
# Speed: 0.9ms preprocess, 160.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.6ms
# Speed: 2.7ms preprocess, 159.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.0ms
# Speed: 0.9ms preprocess, 170.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.1ms
# Speed: 0.9ms preprocess, 156.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.1ms
# Speed: 0.9ms preprocess, 158.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 160.3ms
# Speed: 0.9ms preprocess, 160.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 155.2ms
# Speed: 0.9ms preprocess, 155.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.7ms
# Speed: 0.9ms preprocess, 158.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 156.1ms
# ...
#
# 0: 640x384 1 person, 163.4ms
# Speed: 0.7ms preprocess, 163.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.5ms
# Speed: 0.8ms preprocess, 167.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.8ms
# Speed: 0.8ms preprocess, 164.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.4ms
# Speed: 2.4ms preprocess, 169.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.7ms
# Speed: 0.8ms preprocess, 166.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.8ms
# Speed: 0.8ms preprocess, 170.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.5ms
# Speed: 0.8ms preprocess, 165.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 178.7ms
# Speed: 3.2ms preprocess, 178.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.5ms
# Speed: 0.7ms preprocess, 168.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.0ms
# Speed: 0.7ms preprocess, 171.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.3ms
# Speed: 0.8ms preprocess, 168.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.0ms
# Speed: 0.8ms preprocess, 167.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.0ms
# Speed: 0.8ms preprocess, 166.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.5ms
# Speed: 0.7ms preprocess, 168.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 172.5ms
# Speed: 0.8ms preprocess, 172.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.9ms
# Speed: 0.7ms preprocess, 167.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.8ms
# Speed: 0.7ms preprocess, 171.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.3ms
# Speed: 0.8ms preprocess, 171.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.9ms
# Speed: 0.7ms preprocess, 170.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.9ms
# Speed: 0.7ms preprocess, 162.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.8ms
# Speed: 0.8ms preprocess, 165.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.1ms
# Speed: 0.7ms preprocess, 163.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.6ms
# Speed: 0.8ms preprocess, 168.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.4ms
# Speed: 0.8ms preprocess, 171.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.6ms
# Speed: 0.7ms preprocess, 166.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 177.5ms
# Speed: 1.0ms preprocess, 177.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.8ms
# Speed: 0.7ms preprocess, 165.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.5ms
# Speed: 0.8ms preprocess, 169.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.8ms
# Speed: 0.6ms preprocess, 165.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.6ms
# Speed: 0.8ms preprocess, 163.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 172.1ms
# Speed: 0.8ms preprocess, 172.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.4ms
# Speed: 0.7ms preprocess, 165.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.2ms
# Speed: 0.8ms preprocess, 164.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.7ms
# Speed: 0.9ms preprocess, 166.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.4ms
# Speed: 0.8ms preprocess, 163.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.6ms
# Speed: 0.7ms preprocess, 162.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 158.5ms
# Speed: 0.8ms preprocess, 158.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.8ms
# Speed: 0.8ms preprocess, 164.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.2ms
# Speed: 0.9ms preprocess, 167.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.2ms
# Speed: 0.8ms preprocess, 170.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.6ms
# Speed: 0.8ms preprocess, 175.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.4ms
# Speed: 0.8ms preprocess, 161.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.0ms
# Speed: 0.7ms preprocess, 169.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 173.6ms
# Speed: 0.9ms preprocess, 173.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.7ms
# Speed: 0.8ms preprocess, 167.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.6ms
# Speed: 0.8ms preprocess, 168.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.8ms
# Speed: 0.8ms preprocess, 167.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.7ms
# Speed: 0.7ms preprocess, 165.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 181.3ms
# Speed: 0.8ms preprocess, 181.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.6ms
# Speed: 0.8ms preprocess, 161.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.5ms
# Speed: 0.7ms preprocess, 167.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.6ms
# Speed: 0.7ms preprocess, 169.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 173.1ms
# Speed: 0.8ms preprocess, 173.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.0ms
# Speed: 1.0ms preprocess, 163.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.0ms
# Speed: 0.7ms preprocess, 165.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.6ms
# Speed: 0.7ms preprocess, 163.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.2ms
# Speed: 0.7ms preprocess, 170.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 173.2ms
# Speed: 3.4ms preprocess, 173.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 177.8ms
# Speed: 0.8ms preprocess, 177.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 183.1ms
# Speed: 0.7ms preprocess, 183.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 183.5ms
# Speed: 0.8ms preprocess, 183.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.1ms
# Speed: 0.8ms preprocess, 163.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.9ms
# Speed: 0.7ms preprocess, 165.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.8ms
# Speed: 0.8ms preprocess, 169.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.5ms
# Speed: 0.8ms preprocess, 167.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.7ms
# Speed: 0.7ms preprocess, 170.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.6ms
# Speed: 0.8ms preprocess, 171.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.2ms
# Speed: 0.8ms preprocess, 164.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.6ms
# Speed: 0.9ms preprocess, 166.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.6ms
# Speed: 0.8ms preprocess, 167.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.5ms
# Speed: 0.8ms preprocess, 165.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.6ms
# Speed: 0.9ms preprocess, 168.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.9ms
# Speed: 0.8ms preprocess, 161.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.7ms
# Speed: 0.8ms preprocess, 163.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 182.6ms
# Speed: 0.8ms preprocess, 182.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.5ms
# Speed: 0.7ms preprocess, 159.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.1ms
# Speed: 0.8ms preprocess, 171.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.1ms
# Speed: 0.8ms preprocess, 163.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.1ms
# Speed: 0.7ms preprocess, 168.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 159.5ms
# Speed: 0.8ms preprocess, 159.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.5ms
# Speed: 0.8ms preprocess, 167.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.5ms
# Speed: 0.7ms preprocess, 167.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 172.2ms
# Speed: 1.3ms preprocess, 172.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.9ms
# Speed: 0.8ms preprocess, 167.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.7ms
# Speed: 0.9ms preprocess, 163.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.1ms
# Speed: 0.8ms preprocess, 165.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.6ms
# Speed: 0.8ms preprocess, 165.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.8ms
# Speed: 0.8ms preprocess, 165.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 173.9ms
# Speed: 0.7ms preprocess, 173.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.9ms
# Speed: 0.7ms preprocess, 168.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.1ms
# Speed: 0.7ms preprocess, 171.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.1ms
# Speed: 0.7ms preprocess, 167.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.9ms
# Speed: 0.7ms preprocess, 171.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.0ms
# Speed: 0.8ms preprocess, 169.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 191.5ms
# Speed: 0.8ms preprocess, 191.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.1ms
# Speed: 0.9ms preprocess, 167.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 161.3ms
# Speed: 0.7ms preprocess, 161.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.2ms
# Speed: 0.8ms preprocess, 170.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.3ms
# Speed: 0.9ms preprocess, 165.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.3ms
# Speed: 0.7ms preprocess, 164.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.8ms
# Speed: 0.8ms preprocess, 168.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.1ms
# Speed: 1.2ms preprocess, 168.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 166.7ms
# Speed: 0.7ms preprocess, 166.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.8ms
# Speed: 0.8ms preprocess, 170.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.0ms
# Speed: 0.8ms preprocess, 168.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 181.1ms
# Speed: 0.9ms preprocess, 181.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.3ms
# Speed: 0.7ms preprocess, 171.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 162.9ms
# Speed: 0.7ms preprocess, 162.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.5ms
# Speed: 0.8ms preprocess, 170.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 173.4ms
# Speed: 4.6ms preprocess, 173.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.1ms
# Speed: 1.4ms preprocess, 170.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 169.9ms
# Speed: 1.0ms preprocess, 169.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 167.0ms
# Speed: 0.8ms preprocess, 167.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.6ms
# Speed: 0.7ms preprocess, 164.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 164.2ms
# Speed: 0.8ms preprocess, 164.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.8ms
# Speed: 0.7ms preprocess, 165.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 168.5ms
# Speed: 0.7ms preprocess, 168.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 170.5ms
# Speed: 0.8ms preprocess, 170.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 165.9ms
# Speed: 0.8ms preprocess, 165.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 163.6ms
# Speed: 1.0ms preprocess, 163.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 172.1ms
# Speed: 0.7ms preprocess, 172.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 199.1ms
# Speed: 1.3ms preprocess, 199.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 175.8ms
# Speed: 0.7ms preprocess, 175.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 171.1ms
# Speed: 0.8ms preprocess, 171.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Output saved: /Users/shruti.kalaskar/Documents/Northwestern/Spring 2025/Computer Vision/Project/lunge_reformer_2_output.mp4
